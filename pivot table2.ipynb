# %%
import pandas as pd

# %%
car=pd.read_excel("C:/Users/HP/Downloads/Car data saved.xlsx")

# %%
car
# Out:
#                       Name  Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)  \
# 0            Mahindra Thar             11.35             17.60         15.20
# 1             Maruti Swift              6.49              9.60         24.80
# 2         Mahindra Scorpio             13.62             17.42         22.00
# 3               Tata Punch              6.13             10.20         20.09
# 4            Hyundai Creta             11.00             20.15         17.40
# 5          Mahindra XUV700             13.99             26.04         15.00
# 6               Tata Nexon              8.00             15.80         17.44
# 7            Maruti Brezza              8.34             14.14         17.38
# 8         Mahindra XUV 3XO              7.49             15.49         18.89
# 9          Toyota Fortuner             33.43             51.44         10.00
# 10         Mahindra Bolero              9.79             10.91         16.00
# ...

# %%
pivot=car.pivot_table(index='Name', columns='Type', values='Onroad Price', aggfunc='min')
pivot
# Out:
# Type                        Diesel        Petrol
# Name
# Hyundai Creta                   NaN    12,73,662
# Hyundai Exter                   NaN     6,98,009
# Kia Seltos                      NaN    12,42,525
# Land Rover Defender             NaN  1,11,70,278
# Land Rover Range Rover  2,77,25,295          NaN
# Mahindra Bolero           11,12,348          NaN
# Mahindra Scorpio          16,50,075          NaN
# Mahindra Scorpio N              NaN    16,13,522
# Mahindra Thar                   NaN    16,71,667
# Mahindra XUV 3XO                NaN     8,41,750
# Mahindra XUV700                 NaN    16,36,062
# Maruti Baleno                   NaN     7,51,770
# Maruti Brezza                   NaN     9,32,544
# Maruti Ertiga                   NaN     9,68,665
# Maruti FRONX                    NaN     8,39,546
# Maruti Swift                    NaN     7,28,516
# Tata Harrier              17,88,393          NaN
# Tata Nexon                      NaN     8,98,185
# ...

# %%
pivot=car.pivot_table(
    index='Name', columns='Type', 
    values='Onroad Price', 
    aggfunc='min').fillna(0)
pivot
# Out:
# Type                        Diesel        Petrol
# Name
# Hyundai Creta                     0    12,73,662
# Hyundai Exter                     0     6,98,009
# Kia Seltos                        0    12,42,525
# Land Rover Defender               0  1,11,70,278
# Land Rover Range Rover  2,77,25,295            0
# Mahindra Bolero           11,12,348            0
# Mahindra Scorpio          16,50,075            0
# Mahindra Scorpio N                0    16,13,522
# Mahindra Thar                     0    16,71,667
# Mahindra XUV 3XO                  0     8,41,750
# Mahindra XUV700                   0    16,36,062
# Maruti Baleno                     0     7,51,770
# Maruti Brezza                     0     9,32,544
# Maruti Ertiga                     0     9,68,665
# Maruti FRONX                      0     8,39,546
# Maruti Swift                      0     7,28,516
# Tata Harrier              17,88,393            0
# Tata Nexon                        0     8,98,185
# ...

# %%
preference=pd.DataFrame(
    {
        'Preference':['Yes', 'No'],
        'Type': ['Petrol', 'diesel']
    }
)

# %%
preference
# Out:
#   Preference    Type
# 0        Yes  Petrol
# 1         No  diesel

# %%
car['Type'].unique()
# Out:
# array(['Petrol', 'Diesel\xa0'], dtype=object)

# %%
car['Type']=car['Type'].str.strip()
car['Type'].unique()
# Out:
# array(['Petrol', 'Diesel'], dtype=object)

# %%
df=df.replace('Diesel\xa0','Diesel')

# %%
merged_df=pd.merge(car, preference, on='Type', how='left')
merged_df
# Out:
#                       Name  Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)  \
# 0            Mahindra Thar             11.35             17.60         15.20
# 1             Maruti Swift              6.49              9.60         24.80
# 2         Mahindra Scorpio             13.62             17.42         22.00
# 3               Tata Punch              6.13             10.20         20.09
# 4            Hyundai Creta             11.00             20.15         17.40
# 5          Mahindra XUV700             13.99             26.04         15.00
# 6               Tata Nexon              8.00             15.80         17.44
# 7            Maruti Brezza              8.34             14.14         17.38
# 8         Mahindra XUV 3XO              7.49             15.49         18.89
# 9          Toyota Fortuner             33.43             51.44         10.00
# 10         Mahindra Bolero              9.79             10.91         16.00
# ...

# %%
joined_df=car.set_index('Type').join(preference.set_index('Type'))
joined_df
# Out:
#                           Name  Min Price (Lakh)  Max Price (Lakh)  \
# Type
# Petrol           Mahindra Thar             11.35             17.60
# Petrol            Maruti Swift              6.49              9.60
# Diesel        Mahindra Scorpio             13.62             17.42
# Petrol              Tata Punch              6.13             10.20
# Petrol           Hyundai Creta             11.00             20.15
# Petrol         Mahindra XUV700             13.99             26.04
# Petrol              Tata Nexon              8.00             15.80
# Petrol           Maruti Brezza              8.34             14.14
# Petrol        Mahindra XUV 3XO              7.49             15.49
# Petrol         Toyota Fortuner             33.43             51.44
# Diesel         Mahindra Bolero              9.79             10.91
# Diesel    Toyota Innova Crysta             19.99             26.55
# Petrol           Maruti Ertiga              8.69             13.03
# ...

# %%
joined_df=car.set_index('Type').join(preference.set_index('Type'))
joined_df.reset_index()
# Out:
#       Type                    Name  Min Price (Lakh)  Max Price (Lakh)  \
# 0   Petrol           Mahindra Thar             11.35             17.60
# 1   Petrol            Maruti Swift              6.49              9.60
# 2   Diesel        Mahindra Scorpio             13.62             17.42
# 3   Petrol              Tata Punch              6.13             10.20
# 4   Petrol           Hyundai Creta             11.00             20.15
# 5   Petrol         Mahindra XUV700             13.99             26.04
# 6   Petrol              Tata Nexon              8.00             15.80
# 7   Petrol           Maruti Brezza              8.34             14.14
# 8   Petrol        Mahindra XUV 3XO              7.49             15.49
# 9   Petrol         Toyota Fortuner             33.43             51.44
# 10  Diesel         Mahindra Bolero              9.79             10.91
# 11  Diesel    Toyota Innova Crysta             19.99             26.55
# ...
